# %% [markdown]
# # Some simple demos of approaches to Bayesian inference with unknown errors

# %%
from collections import OrderedDict

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np
from scipy import stats
from scipy.stats import invgamma, norm

# %%
import corner

# %%
import rxmc
# Out:
# Using database version X4-2024-12-31 located in: /home/beyerk/db/exfor/unpack_exfor-2024/X4-2024-12-31

# %%
true_params = OrderedDict(
    [
        ("m", 2),
        ("b", 4),
    ]
)

# %%
rng = np.random.default_rng(13)

# %%
noise = 0.05
N = 20
x_data = np.linspace(0, 1, N)
y_true = true_params["m"] * x_data + true_params["b"]
y_err = np.array([rng.normal(0, noise * y) for y in y_true])
y_data = y_true + y_err

# %%
class LinearModel(rxmc.physical_model.PhysicalModel):
    def __init__(self):
        params = [
            rxmc.params.Parameter("m", float, "no-units"),
            rxmc.params.Parameter("b", float, "y-units"),
        ]
        super().__init__(params)

    def evaluate(self, observation, m, b):
        return self.y(observation.x, m, b)

    def y(self, x, m, b):
        # useful to have a function hat takes in an array-like x
        # rather than an Observation, e.g. for plotting
        return m * x + b

# %%
prior_mean = OrderedDict(
    [
        ("m", 1),
        ("b", 5),
    ]
)
prior_std_dev = OrderedDict(
    [
        ("m", 1),
        ("b", 1),
    ]
)

# %%
covariance = np.diag(list(prior_std_dev.values())) ** 2
mean = np.array(list(prior_mean.values()))
prior_distribution = stats.multivariate_normal(mean, covariance)

# %%
my_model = LinearModel()

# %%
observation = rxmc.observation.Observation(
    x=x_data,
    y=y_data,
    y_stat_err=y_true * noise,
)

# %%
plt.errorbar(
    x_data,
    y_data,
    noise * y_data,
    color="k",
    marker="o",
    linestyle="none",
    label="experiment with bias",
)
plt.plot(x_data, y_true, "k--", label="truth")

# %%
likelihood = rxmc.likelihood_model.UnknownNoiseFractionErrorModel()

# %%
constraints = rxmc.evidence.Evidence(
    parametric_constraints=[
        rxmc.constraint.Constraint(
            [observation],
            my_model,
            likelihood,
        )
    ]
)

# %%
noise_prior = stats.norm(loc=np.log(0.1), scale=1)

# %%
def proposal_distribution_noise(x, rng):
    return np.atleast_1d(stats.norm.rvs(loc=x, scale=0.1, random_state=rng))

# %%
def proposal_distribution(x, rng):
    return stats.multivariate_normal.rvs(
        mean=x, cov=prior_distribution.cov / 1000, random_state=rng
    )

# %%
noise_sampling_config = rxmc.param_sampling.MetropolisHastingsSampler(
    params=likelihood.params,
    starting_location=np.array(noise_prior.mean()),
    proposal=proposal_distribution_noise,
    prior=noise_prior,
)

# %%
sampling_config = rxmc.param_sampling.MetropolisHastingsSampler(
    params=my_model.params,
    starting_location=prior_distribution.mean,
    proposal=proposal_distribution,
    prior=prior_distribution,
)

# %%
walker = rxmc.walker.Walker(
    sampling_config,
    constraints,
    likelihood_sample_confs=[noise_sampling_config],
)

# %%
lm = walker.evidence.parametric_constraints[0].likelihood
o = walker.evidence.parametric_constraints[0].observations[0]

# %%
ym = y_true

# %%
log_noise_grid = np.linspace(-4, 2, 1000)
logl = np.array([lm.log_likelihood(o, ym, eta) for eta in log_noise_grid])
chi2 = np.array([lm.chi2(o, ym, eta) for eta in log_noise_grid])
cov = [lm.covariance(o, ym, eta) for eta in log_noise_grid]
logdet = np.array([np.linalg.slogdet(c)[1] for c in cov])

# %%
mu = np.array(list(true_params.values()))

# %%
logl_gibbs = np.array(
    [
        walker.evidence.parametric_constraints[0].marginal_log_likelihood([ym], eta)
        for eta in log_noise_grid
    ]
)

# %%
logl_w = [
    walker.evidence.log_likelihood(mu, [np.atleast_1d(eta)]) for eta in log_noise_grid
]

# %%
# plt.plot(noise_grid, logl, label=r"$\mathcal{L}(x)$")
plt.plot(log_noise_grid, -0.5 * chi2, label=r"-1/2 $\chi^2$")
plt.plot(log_noise_grid, -0.5 * logdet, label=r"$-1/2 |\Sigma|$")
plt.plot(log_noise_grid, logl_w, label=r"w")
plt.plot(log_noise_grid, logl_gibbs, ":", label=r"marginal")

# plt.plot(noise_grid,  -0.5* (logdet+chi2 + np.log(2*np.pi)*N), "--", label=r"$-(\chi^2 + |\Sigma| + N\log{2\pi})/2$")
plt.vlines(np.log(noise), -300, 300, color="k", linestyles=[":"])
plt.legend(loc="lower right")

# %%
# %%time
walker.walk(n_steps=20000, burnin=2000, batch_size=100)
# Out:
# Burn-in batch 1/20 completed, 100 steps.
# Burn-in batch 2/20 completed, 100 steps.
# Burn-in batch 3/20 completed, 100 steps.
# Burn-in batch 4/20 completed, 100 steps.
# Burn-in batch 5/20 completed, 100 steps.
# Burn-in batch 6/20 completed, 100 steps.
# Burn-in batch 7/20 completed, 100 steps.
# Burn-in batch 8/20 completed, 100 steps.
# Burn-in batch 9/20 completed, 100 steps.
# Burn-in batch 10/20 completed, 100 steps.
# Burn-in batch 11/20 completed, 100 steps.
# Burn-in batch 12/20 completed, 100 steps.
# Burn-in batch 13/20 completed, 100 steps.
# Burn-in batch 14/20 completed, 100 steps.
# Burn-in batch 15/20 completed, 100 steps.
# Burn-in batch 16/20 completed, 100 steps.
# Burn-in batch 17/20 completed, 100 steps.
# Burn-in batch 18/20 completed, 100 steps.
# Burn-in batch 19/20 completed, 100 steps.
# Burn-in batch 20/20 completed, 100 steps.
# Batch: 1/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.890
#   Likelihood parameter acceptance fractions: [0.85]
# Batch: 2/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.910
#   Likelihood parameter acceptance fractions: [0.87]
# Batch: 3/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 4/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.900
#   Likelihood parameter acceptance fractions: [0.79]
# Batch: 5/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.920
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 6/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.900
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 7/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.790
#   Likelihood parameter acceptance fractions: [0.83]
# Batch: 8/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.810
#   Likelihood parameter acceptance fractions: [0.75]
# Batch: 9/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.760
#   Likelihood parameter acceptance fractions: [0.92]
# Batch: 10/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.810
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 11/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.76]
# Batch: 12/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.850
#   Likelihood parameter acceptance fractions: [0.86]
# Batch: 13/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.880
#   Likelihood parameter acceptance fractions: [0.82]
# Batch: 14/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.83]
# Batch: 15/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.800
#   Likelihood parameter acceptance fractions: [0.8]
# Batch: 16/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.850
#   Likelihood parameter acceptance fractions: [0.85]
# Batch: 17/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 18/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.860
#   Likelihood parameter acceptance fractions: [0.79]
# Batch: 19/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.770
#   Likelihood parameter acceptance fractions: [0.74]
# Batch: 20/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.930
#   Likelihood parameter acceptance fractions: [0.86]
# Batch: 21/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.750
#   Likelihood parameter acceptance fractions: [0.76]
# Batch: 22/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.900
#   Likelihood parameter acceptance fractions: [0.87]
# Batch: 23/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.730
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 24/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.860
#   Likelihood parameter acceptance fractions: [0.77]
# Batch: 25/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.790
#   Likelihood parameter acceptance fractions: [0.72]
# Batch: 26/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.810
#   Likelihood parameter acceptance fractions: [0.8]
# Batch: 27/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.870
#   Likelihood parameter acceptance fractions: [0.82]
# Batch: 28/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.790
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 29/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.8]
# Batch: 30/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.740
#   Likelihood parameter acceptance fractions: [0.8]
# Batch: 31/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.85]
# Batch: 32/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.850
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 33/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.82]
# Batch: 34/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.810
#   Likelihood parameter acceptance fractions: [0.79]
# Batch: 35/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.860
#   Likelihood parameter acceptance fractions: [0.73]
# Batch: 36/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.77]
# Batch: 37/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.780
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 38/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.880
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 39/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.900
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 40/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.850
#   Likelihood parameter acceptance fractions: [0.79]
# Batch: 41/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.700
#   Likelihood parameter acceptance fractions: [0.75]
# Batch: 42/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.940
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 43/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 44/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.77]
# Batch: 45/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.870
#   Likelihood parameter acceptance fractions: [0.85]
# Batch: 46/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.8]
# Batch: 47/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.860
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 48/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.76]
# Batch: 49/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.780
#   Likelihood parameter acceptance fractions: [0.82]
# Batch: 50/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.75]
# Batch: 51/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.870
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 52/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.900
#   Likelihood parameter acceptance fractions: [0.82]
# Batch: 53/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.840
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 54/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.890
#   Likelihood parameter acceptance fractions: [0.79]
# Batch: 55/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.840
#   Likelihood parameter acceptance fractions: [0.75]
# Batch: 56/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.850
#   Likelihood parameter acceptance fractions: [0.82]
# Batch: 57/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.810
#   Likelihood parameter acceptance fractions: [0.77]
# Batch: 58/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.850
#   Likelihood parameter acceptance fractions: [0.88]
# Batch: 59/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.750
#   Likelihood parameter acceptance fractions: [0.82]
# Batch: 60/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.780
#   Likelihood parameter acceptance fractions: [0.76]
# Batch: 61/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.83]
# Batch: 62/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.880
#   Likelihood parameter acceptance fractions: [0.8]
# Batch: 63/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.880
#   Likelihood parameter acceptance fractions: [0.8]
# Batch: 64/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.910
#   Likelihood parameter acceptance fractions: [0.76]
# Batch: 65/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.800
#   Likelihood parameter acceptance fractions: [0.83]
# Batch: 66/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.750
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 67/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.75]
# Batch: 68/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.77]
# Batch: 69/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.810
#   Likelihood parameter acceptance fractions: [0.85]
# Batch: 70/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.840
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 71/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.920
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 72/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.710
#   Likelihood parameter acceptance fractions: [0.86]
# Batch: 73/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.870
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 74/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.810
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 75/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.770
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 76/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.810
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 77/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.840
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 78/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.770
#   Likelihood parameter acceptance fractions: [0.8]
# Batch: 79/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.87]
# Batch: 80/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.840
#   Likelihood parameter acceptance fractions: [0.82]
# Batch: 81/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.940
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 82/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.780
#   Likelihood parameter acceptance fractions: [0.83]
# Batch: 83/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.850
#   Likelihood parameter acceptance fractions: [0.87]
# Batch: 84/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.780
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 85/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.890
#   Likelihood parameter acceptance fractions: [0.86]
# Batch: 86/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 87/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 88/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.840
#   Likelihood parameter acceptance fractions: [0.73]
# Batch: 89/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.840
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 90/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.950
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 91/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.860
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 92/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 93/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.740
#   Likelihood parameter acceptance fractions: [0.8]
# Batch: 94/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.790
#   Likelihood parameter acceptance fractions: [0.88]
# Batch: 95/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.8]
# Batch: 96/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 97/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.880
#   Likelihood parameter acceptance fractions: [0.83]
# Batch: 98/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.860
#   Likelihood parameter acceptance fractions: [0.82]
# Batch: 99/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.900
#   Likelihood parameter acceptance fractions: [0.77]
# Batch: 100/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.860
#   Likelihood parameter acceptance fractions: [0.86]
# Batch: 101/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.710
#   Likelihood parameter acceptance fractions: [0.75]
# Batch: 102/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.810
#   Likelihood parameter acceptance fractions: [0.73]
# Batch: 103/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.720
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 104/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.910
#   Likelihood parameter acceptance fractions: [0.75]
# Batch: 105/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.850
#   Likelihood parameter acceptance fractions: [0.89]
# Batch: 106/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 107/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.770
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 108/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.930
#   Likelihood parameter acceptance fractions: [0.76]
# Batch: 109/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 110/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.800
#   Likelihood parameter acceptance fractions: [0.75]
# Batch: 111/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.730
#   Likelihood parameter acceptance fractions: [0.86]
# Batch: 112/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.870
#   Likelihood parameter acceptance fractions: [0.79]
# Batch: 113/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.850
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 114/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.900
#   Likelihood parameter acceptance fractions: [0.89]
# Batch: 115/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.8]
# Batch: 116/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.840
#   Likelihood parameter acceptance fractions: [0.8]
# Batch: 117/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 118/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.840
#   Likelihood parameter acceptance fractions: [0.76]
# Batch: 119/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.860
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 120/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.8]
# Batch: 121/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.800
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 122/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.790
#   Likelihood parameter acceptance fractions: [0.83]
# Batch: 123/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.880
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 124/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.85]
# Batch: 125/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.85]
# Batch: 126/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.880
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 127/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.840
#   Likelihood parameter acceptance fractions: [0.75]
# Batch: 128/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 129/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.710
#   Likelihood parameter acceptance fractions: [0.83]
# Batch: 130/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.930
#   Likelihood parameter acceptance fractions: [0.69]
# Batch: 131/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.86]
# Batch: 132/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.910
#   Likelihood parameter acceptance fractions: [0.73]
# Batch: 133/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.750
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 134/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.910
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 135/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.82]
# Batch: 136/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.810
#   Likelihood parameter acceptance fractions: [0.86]
# Batch: 137/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.750
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 138/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.850
#   Likelihood parameter acceptance fractions: [0.85]
# Batch: 139/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.870
#   Likelihood parameter acceptance fractions: [0.93]
# Batch: 140/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.88]
# Batch: 141/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.880
#   Likelihood parameter acceptance fractions: [0.86]
# Batch: 142/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.800
#   Likelihood parameter acceptance fractions: [0.83]
# Batch: 143/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.840
#   Likelihood parameter acceptance fractions: [0.8]
# Batch: 144/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.910
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 145/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.850
#   Likelihood parameter acceptance fractions: [0.83]
# Batch: 146/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.850
#   Likelihood parameter acceptance fractions: [0.89]
# Batch: 147/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.890
#   Likelihood parameter acceptance fractions: [0.8]
# Batch: 148/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.810
#   Likelihood parameter acceptance fractions: [0.76]
# Batch: 149/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.810
#   Likelihood parameter acceptance fractions: [0.8]
# Batch: 150/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.840
#   Likelihood parameter acceptance fractions: [0.85]
# Batch: 151/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.83]
# Batch: 152/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.850
#   Likelihood parameter acceptance fractions: [0.85]
# Batch: 153/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.840
#   Likelihood parameter acceptance fractions: [0.79]
# Batch: 154/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.900
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 155/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.890
#   Likelihood parameter acceptance fractions: [0.8]
# Batch: 156/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 157/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.850
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 158/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.840
#   Likelihood parameter acceptance fractions: [0.76]
# Batch: 159/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.860
#   Likelihood parameter acceptance fractions: [0.85]
# Batch: 160/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.840
#   Likelihood parameter acceptance fractions: [0.9]
# Batch: 161/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.880
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 162/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.82]
# Batch: 163/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.850
#   Likelihood parameter acceptance fractions: [0.82]
# Batch: 164/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.85]
# Batch: 165/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.800
#   Likelihood parameter acceptance fractions: [0.74]
# Batch: 166/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.760
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 167/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.710
#   Likelihood parameter acceptance fractions: [0.83]
# Batch: 168/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.860
#   Likelihood parameter acceptance fractions: [0.82]
# Batch: 169/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.890
#   Likelihood parameter acceptance fractions: [0.79]
# Batch: 170/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.840
#   Likelihood parameter acceptance fractions: [0.85]
# Batch: 171/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.760
#   Likelihood parameter acceptance fractions: [0.82]
# Batch: 172/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.83]
# Batch: 173/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.810
#   Likelihood parameter acceptance fractions: [0.82]
# Batch: 174/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 175/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.810
#   Likelihood parameter acceptance fractions: [0.81]
# Batch: 176/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.880
#   Likelihood parameter acceptance fractions: [0.83]
# Batch: 177/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.880
#   Likelihood parameter acceptance fractions: [0.79]
# Batch: 178/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 179/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.690
#   Likelihood parameter acceptance fractions: [0.83]
# Batch: 180/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.790
#   Likelihood parameter acceptance fractions: [0.76]
# Batch: 181/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.930
#   Likelihood parameter acceptance fractions: [0.82]
# Batch: 182/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.800
#   Likelihood parameter acceptance fractions: [0.75]
# Batch: 183/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.810
#   Likelihood parameter acceptance fractions: [0.77]
# Batch: 184/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.8]
# Batch: 185/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.860
#   Likelihood parameter acceptance fractions: [0.85]
# Batch: 186/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.900
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 187/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.870
#   Likelihood parameter acceptance fractions: [0.83]
# Batch: 188/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.780
#   Likelihood parameter acceptance fractions: [0.77]
# Batch: 189/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.770
#   Likelihood parameter acceptance fractions: [0.83]
# Batch: 190/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.790
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 191/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.880
#   Likelihood parameter acceptance fractions: [0.85]
# Batch: 192/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.800
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 193/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.830
#   Likelihood parameter acceptance fractions: [0.82]
# Batch: 194/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.850
#   Likelihood parameter acceptance fractions: [0.84]
# Batch: 195/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.860
#   Likelihood parameter acceptance fractions: [0.83]
# Batch: 196/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.800
#   Likelihood parameter acceptance fractions: [0.71]
# Batch: 197/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.840
#   Likelihood parameter acceptance fractions: [0.76]
# Batch: 198/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.820
#   Likelihood parameter acceptance fractions: [0.85]
# Batch: 199/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.790
#   Likelihood parameter acceptance fractions: [0.78]
# Batch: 200/200 completed, 100 steps.
#   Model parameter acceptance fraction: 0.850
#   Likelihood parameter acceptance fractions: [0.84]
# CPU times: user 14.4 s, sys: 116 ms, total: 14.5 s
# Wall time: 14.4 s
# (0.8328, [0.81])

# %%
def plot_chains(walker, model, true_params):
    fig, axes = plt.subplots(
        walker.model_chain.shape[1] + 3, 1, figsize=(8, 8), sharex=True
    )
    for i in range(walker.model_chain.shape[1]):
        axes[i].plot(walker.model_chain[:, i])
        axes[i].set_ylabel(f"${model.params[i].latex_name}$ [{model.params[i].unit}]")
        true_value = true_params[model.params[i].name]
        axes[i].hlines(true_value, 0, len(walker.model_chain), "r", linestyle="--")

    axes[-3].plot(walker.log_posterior_record)
    axes[-3].set_ylabel(r"$\log{\mathcal{L}(\alpha_i | \mathcal{O})}$")

    lmp = walker.likelihood_sample_confs[0].params[0]
    axes[-2].plot(walker.likelihood_chain[0])
    axes[-2].set_ylabel(f"${lmp.latex_name}$ [{lmp.unit}]")
    axes[-2].hlines(np.log(noise), 0, len(walker.model_chain), "r", linestyle="--")

    axes[-1].plot(walker.log_posterior_record_lm[0])
    axes[-1].set_ylabel(r"$\log{\mathcal{L}(\alpha_i | \mathcal{O})}$")

    axes[-1].set_xlabel(r"$i$")
    # plt.legend(title="chains", ncol=3,)

# %%
plot_chains(walker, my_model, true_params)

# %%
def plot_posterior_corner(walker):
    fig = corner.corner(
        np.hstack([walker.model_chain, walker.likelihood_chain[0]]),
        labels=[p.name for p in my_model.params]
        + [walker.likelihood_sample_confs[0].params[0].name],
        label="posterior",
        truths=[true_params["m"], true_params["b"], np.log(noise)],
    )
    fig.suptitle("posterior")

# %%
plot_posterior_corner(walker)

# %%
def plot_predictive_post(walker, model, x, y_exp, y_err, y_true):
    n_posterior_samples = walker.model_chain.shape[0]
    y = np.zeros((n_posterior_samples, len(x)))
    for i in range(n_posterior_samples):
        sample = walker.model_chain[i, :]
        y[i, :] = model.y(x, *sample)

    upper, lower = np.percentile(y, [5, 95], axis=0)
    plt.errorbar(
        x,
        y_exp,
        noise * y_data,
        color="k",
        marker="o",
        linestyle="none",
        label="experiment with bias",
    )

    plt.plot(x, y_true, "k--", label="truth")
    plt.fill_between(
        x,
        lower,
        upper,
        alpha=0.5,
        zorder=2,
        label=r"posterior inner 90$^\text{th}$ pctl",
    )
    return upper, lower

# %%
upper, lower = plot_predictive_post(walker, my_model, x_data, y_data, noise, y_true)
